# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import time
from scipy.spatial.distance import pdist
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
from random import randint
from gap.Gap import Gap

# %%
n_samples = 1500
random_state = 170
X, y = make_blobs(n_samples=n_samples, n_features=2, centers=5, cluster_std=1.5, random_state=random_state)

plt.figure()

plt.scatter(X[:,0],X[:,1])
plt.show()
plt.close()

gap = Gap()
gap.gap_statistic(X)
print()
print("The clusters number is ", gap.gap_max())
# Out:
# Cicle number 1 time: 0.36165600000003906
# Cicle number 2 time: 0.6764024999999947
# Cicle number 3 time: 0.852524199999948
# Cicle number 4 time: 0.8192720000000691
# Cicle number 5 time: 1.0371368000000984
# Cicle number 6 time: 1.3416706000000431
# Cicle number 7 time: 1.4798888999999917
# Cicle number 8 time: 1.6210029000000077
# Cicle number 9 time: 1.8292216999999482
# Cicle number 10 time: 1.9206996000000345
# Cicle number 11 time: 1.9785851999999977
# Cicle number 12 time: 2.1172663999999486
# Cicle number 13 time: 2.2679425999999694
# Cicle number 14 time: 2.462651199999982
# Cicle number 15 time: 2.4899528999999347
# Cicle number 16 time: 2.707503299999985
# Cicle number 17 time: 3.2457807999999204
# Cicle number 18 time: 3.3094782000000578
# Cicle number 19 time: 3.316822699999989
# Cicle number 20 time: 3.6304391999999552
# Il numero di cluster è  5
