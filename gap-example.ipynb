# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import time
from scipy.spatial.distance import pdist
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
from random import randint
from gap.Gap import Gap

# %%
n_samples = 1500
random_state = 170
X, y = make_blobs(n_samples=n_samples, n_features=2, centers=5, cluster_std=1.5, random_state=random_state)

plt.figure()

plt.scatter(X[:,0],X[:,1])
plt.show()
plt.close()

gap = Gap()
gap.gap_statistic(X)
print()
print("The clusters number is ", gap.gap_max())
# Out:
# Cicle number 1 time: 0.6374830000000005
# Cicle number 2 time: 1.031943
# Cicle number 3 time: 1.4635230000000012
# Cicle number 4 time: 1.4188530000000004
# Cicle number 5 time: 1.8302420000000001
# Cicle number 6 time: 2.070741
# Cicle number 7 time: 2.2477740000000015
# Cicle number 8 time: 2.782808000000001
# Cicle number 9 time: 2.9817849999999986
# Cicle number 10 time: 3.0693699999999993
# Cicle number 11 time: 3.313215999999997
# Cicle number 12 time: 3.468092000000002
# Cicle number 13 time: 3.6156010000000016
# Cicle number 14 time: 3.8152959999999965
# Cicle number 15 time: 4.063702000000006
# Cicle number 16 time: 4.234192999999998
# Cicle number 17 time: 4.245170000000002
# Cicle number 18 time: 4.4280979999999985
# Cicle number 19 time: 4.677008999999998
# Cicle number 20 time: 4.5956389999999985
#
# The clusters number is  5
